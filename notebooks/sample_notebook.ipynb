# %%
import pandas as pd
import os
import numpy as np
from statsmodels.nonparametric.smoothers_lowess import lowess
from scipy.signal import find_peaks, stft
import subprocess
from sklearn.model_selection import LeaveOneOut
from sklearn.svm import SVR
from sklearn.preprocessing import MinMaxScaler
import glob 
from typing import Callable, Any
from datetime import datetime

# %%
from fatigued_face_ml.pipelines.nodes import (
    run_OpenFace,
    get_OpenFace_result,
    csv_to_dataframe,
    get_OpenFace_result,
    json_analyze,
    create_dataset,
    preview_feature_dataset,
    learning_model,
    leave_one_out_evaluate,
    get_diff_from_learningdata
)

# %%
# %load_ext kedro.ipython

# %%
# %reload_kedro

# %%
from kedro.framework.session import KedroSession
session: KedroSession

# 2. context を session から取得
context = session.load_context()

# 3. catalog を context から取得
catalog = context.catalog

# %%
# example: test leave_one_out_evaluate()
data = catalog.load("feature_dataset")
print(type(data))
print(data.columns)

# 優先度はリスト指定＞正規表現指定＞レンジ指定
result_df, exp_params = leave_one_out_evaluate(
    data, 
    vas_num=0, 
    name="white name included in your dataset", 
    au_list=[],
    dataset_name="white dataset name",
    start=2,
    stop=48,
    step=1,
    regex=["^AU\\d+_spectrum_9Hz$"]
)

exp_params
